# %% [markdown]
# # WeatherPy
# ----
#
# #### Observations
# * The plot of latitude versus maximum temperature shows a trend between the two variable, indicating that temperature has a relationship with latitude. The observed temperatures were be highest at around 20 degrees above the equator. Temperatures at latitudes above and below this point tend to be lower.
# * The relationship between temperature and latitude looks like it could be fit with a second degree polynomial. Though the polynomial regression fit of Temperature = 77.65411717174872+ 0.2941614934143051*Latitude + -0.00923128769198287*Latitude^2 looks good, it does not have a very high R squared, 0.54.
# * Humidity and cloudiness do not have visible trends with latutide.  In fact, the plot of latitude with each of these predictor variables results in points that appear to be randomly distributed.
# * There was an observed wind speed with a value extremely different from the all other wind speeds in the sample.  The wind speed recorded at Manta, EC was 69.12 mph, while all other wind speeds were below 30 mph. Some research into common weather conditions in Manta indicate that this is not a normal wind speed.  "The average hourly wind speed in Manta experiences significant seasonal variation over the course of the year. The windier part of the year lasts for 7.9 months, from May 16 to January 14, with average wind speeds of more than 9.0 miles per hour." **  On the day the data was observed, there is no documention of a significant weather event, such as a hurricane, that would produce winds that high.
# * The extreme obeservation was removed and the plot of latutide versus wind speed looks uniformly distributed across all values of latitude, indicating that there is not a correlation between wind speed and latitude.
#
# **source: https://weatherspark.com/y/18307/Average-Weather-in-Manta-Ecuador-Year-Round

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
print(len(cities), len(countries))
#cities
# Out:
# 617 617

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#import wrapper for cleaner coding and tqdm for progress bar
import openweathermapy.core as owm
from tqdm import tqdm_notebook

#base url defined
url = "http://api.openweathermap.org/data/2.5/weather?"

#Test data set
#cities = ["Houston", "Dallas","San Antonio", "Fakecity", "Spring"]
#countries = ["US","US","US","US","US"]

#combine city and country to fit wrapper format, define settings for wrapper
city_country = [f"{city},{countries[c]}" for c, city in enumerate(cities)]
settings = {"units": "imperial", "appid": api_key}

all_city_data = []
record_num = 1

print("Begin Data Retreival")
#loop through city list to pull weather information about each city, tqdm_notebook shows a progress bar 
for city in tqdm_notebook(city_country):
    try:
        #define url and obtain response
        weather_response = (owm.get_current(city, **settings))
        #indicate which variable to grab from the API response
        summary = ["name","sys.country", "coord.lat", "coord.lon","dt","main.temp_max","main.humidity","wind.speed","clouds.all"]
        city_data = weather_response(*summary)
        all_city_data.append(city_data)
        #print a confirmation that the record was pulled
        print(f"Processing Record {record_num}, city: {city} ") 
        record_num += 1
    except:
        #message if city is not in the API
        print(f"City {city} not found")

print("Data Retreival Complete")
# Out:
# Begin Data Retreival
# HBox(children=(IntProgress(value=0, max=617), HTML(value='')))
# Processing Record 1, city: villamontes,bo
# Processing Record 2, city: avarua,ck
# Processing Record 3, city: aix-les-bains,fr
# Processing Record 4, city: atuona,pf
# Processing Record 5, city: nieves,mx
# Processing Record 6, city: vaini,to
# Processing Record 7, city: provideniya,ru
# Processing Record 8, city: rikitea,pf
# Processing Record 9, city: katsuura,jp
# Processing Record 10, city: husavik,is
# Processing Record 11, city: kropotkin,ru
# Processing Record 12, city: amberley,nz
# Processing Record 13, city: lagoa,pt
# Processing Record 14, city: ponta do sol,cv
# Processing Record 15, city: bethel,us
# Processing Record 16, city: kaeo,nz
# Processing Record 17, city: afua,br
# Processing Record 18, city: axim,gh
# Processing Record 19, city: manga,br
# Processing Record 20, city: butaritari,ki
# City mataura,pf not found
# Processing Record 21, city: faanui,pf
# Processing Record 22, city: nouadhibou,mr
# Processing Record 23, city: tiksi,ru
# Processing Record 24, city: ust-maya,ru
# Processing Record 25, city: mar del plata,ar
# Processing Record 26, city: ancud,cl
# Processing Record 27, city: ushuaia,ar
# Processing Record 28, city: inhambane,mz
# Processing Record 29, city: santa maria,cv
# City amderma,ru not found
# Processing Record 30, city: solnechnyy,ru
# Processing Record 31, city: hithadhoo,mv
# Processing Record 32, city: chokurdakh,ru
# Processing Record 33, city: cap malheureux,mu
# Processing Record 34, city: balakhta,ru
# Processing Record 35, city: punta arenas,cl
# City uzunkopru,tr not found
# Processing Record 36, city: ciudad bolivar,ve
# Processing Record 37, city: barrow,us
# Processing Record 38, city: ribeira grande,pt
# Processing Record 39, city: sitka,us
# Processing Record 40, city: mogapi,bw
# Processing Record 41, city: puerto madero,mx
# Processing Record 42, city: bolshaya rechka,ru
# Processing Record 43, city: carnarvon,au
# Processing Record 44, city: bolitoc,ph
# Processing Record 45, city: bluff,nz
# Processing Record 46, city: najran,sa
# Processing Record 47, city: killybegs,ie
# Processing Record 48, city: busselton,au
# Processing Record 49, city: lakes entrance,au
# Processing Record 50, city: lavrentiya,ru
# Processing Record 51, city: jamestown,sh
# Processing Record 52, city: gura teghii,ro
# City meyungs,pw not found
# City sentyabrskiy,ru not found
# Processing Record 53, city: saint-augustin,ca
# Processing Record 54, city: iquique,cl
# Processing Record 55, city: ngaoundere,cm
# Processing Record 56, city: zhezkazgan,kz
# Processing Record 57, city: roald,no
# Processing Record 58, city: saldanha,za
# Processing Record 59, city: hermanus,za
# Processing Record 60, city: bjornevatn,no
# Processing Record 61, city: turan,ru
# Processing Record 62, city: dakoro,ne
# Processing Record 63, city: klaksvik,fo
# City taolanaro,mg not found
# Processing Record 64, city: castro,cl
# City vastervik,se not found
# Processing Record 65, city: kodiak,us
# City bengkulu,id not found
# Processing Record 66, city: bambous virieux,mu
# Processing Record 67, city: edson,ca
# City kollumerland,nl not found
# Processing Record 68, city: saint-philippe,re
# Processing Record 69, city: buala,sb
# Processing Record 70, city: saskylakh,ru
# Processing Record 71, city: albany,au
# Processing Record 72, city: staryy nadym,ru
# Processing Record 73, city: mantua,cu
# City belushya guba,ru not found
# Processing Record 74, city: nong chik,th
# Processing Record 75, city: cayenne,gf
# Processing Record 76, city: qaanaaq,gl
# Processing Record 77, city: cidreira,br
# Processing Record 78, city: dodola,et
# Processing Record 79, city: sioux lookout,ca
# Processing Record 80, city: pandan,ph
# Processing Record 81, city: horizonte,br
# Processing Record 82, city: san patricio,mx
# Processing Record 83, city: vargem grande,br
# Processing Record 84, city: sao bernardo,br
# Processing Record 85, city: leningradskiy,ru
# Processing Record 86, city: rosetta,eg
# Processing Record 87, city: hilo,us
# Processing Record 88, city: saint george,bm
# Processing Record 89, city: tshikapa,cd
# Processing Record 90, city: tual,id
# City lata,sb not found
# Processing Record 91, city: denpasar,id
# Processing Record 92, city: georgetown,sh
# Processing Record 93, city: ngunguru,nz
# Processing Record 94, city: puerto ayora,ec
# Processing Record 95, city: chase,ca
# Processing Record 96, city: saint-felicien,ca
# Processing Record 97, city: tautira,pf
# Processing Record 98, city: kapaa,us
# Processing Record 99, city: port elizabeth,za
# Processing Record 100, city: cabo san lucas,mx
# Processing Record 101, city: shingu,jp
# Processing Record 102, city: madimba,tz
# Processing Record 103, city: nantucket,us
# Processing Record 104, city: comodoro rivadavia,ar
# Processing Record 105, city: ambilobe,mg
# Processing Record 106, city: northam,au
# Processing Record 107, city: shimanovsk,ru
# Processing Record 108, city: la ronge,ca
# Processing Record 109, city: nikolskoye,ru
# Processing Record 110, city: pacific grove,us
# Processing Record 111, city: torbay,ca
# Processing Record 112, city: wanlaweyn,so
# Processing Record 113, city: broken hill,au
# Processing Record 114, city: dingle,ie
# City faya,td not found
# Processing Record 115, city: ruteng,id
# Processing Record 116, city: sept-iles,ca
# City djang,cm not found
# Processing Record 117, city: montepuez,mz
# Processing Record 118, city: xinyu,cn
# Processing Record 119, city: arraial do cabo,br
# Processing Record 120, city: hervey bay,au
# Processing Record 121, city: dikson,ru
# Processing Record 122, city: hobart,au
# Processing Record 123, city: balkhash,kz
# Processing Record 124, city: myaundzha,ru
# Processing Record 125, city: los llanos de aridane,es
# Processing Record 126, city: port lincoln,au
# Processing Record 127, city: new norfolk,au
# Processing Record 128, city: gopalpur,in
# Processing Record 129, city: portland,au
# Processing Record 130, city: renqiu,cn
# Processing Record 131, city: yumen,cn
# Processing Record 132, city: elko,us
# City tumannyy,ru not found
# Processing Record 133, city: nome,us
# City hongan,cn not found
# City barentsburg,sj not found
# Processing Record 134, city: horta,pt
# Processing Record 135, city: ulladulla,au
# Processing Record 136, city: tuatapere,nz
# Processing Record 137, city: aykhal,ru
# Processing Record 138, city: nizwa,om
# City illoqqortoormiut,gl not found
# Processing Record 139, city: cherskiy,ru
# Processing Record 140, city: bathsheba,bb
# Processing Record 141, city: nanyamba,tz
# City zolotinka,ru not found
# City toliary,mg not found
# Processing Record 142, city: ilulissat,gl
# Processing Record 143, city: iqaluit,ca
# Processing Record 144, city: candolim,in
# Processing Record 145, city: torre-pacheco,es
# Processing Record 146, city: beringovskiy,ru
# Processing Record 147, city: yar-sale,ru
# Processing Record 148, city: brumunddal,no
# Processing Record 149, city: dillon,us
# Processing Record 150, city: pevek,ru
# Processing Record 151, city: taiyuan,cn
# Processing Record 152, city: victoria,sc
# Processing Record 153, city: port hedland,au
# Processing Record 154, city: vao,nc
# Processing Record 155, city: alto lucero,mx
# Processing Record 156, city: mount gambier,au
# Processing Record 157, city: sann,pk
# Processing Record 158, city: manta,ec
# City pousat,kh not found
# Processing Record 159, city: teguldet,ru
# City airai,pw not found
# Processing Record 160, city: kokkola,fi
# Processing Record 161, city: marsh harbour,bs
# Processing Record 162, city: east london,za
# Processing Record 163, city: hasaki,jp
# Processing Record 164, city: thompson,ca
# Processing Record 165, city: zurrieq,mt
# Processing Record 166, city: kudahuvadhoo,mv
# City mys shmidta,ru not found
# Processing Record 167, city: pangnirtung,ca
# Processing Record 168, city: itoman,jp
# Processing Record 169, city: kitami,jp
# Processing Record 170, city: halifax,ca
# Processing Record 171, city: lundazi,zm
# Processing Record 172, city: narsaq,gl
# Processing Record 173, city: cockburn town,tc
# City kamenskoye,ru not found
# Processing Record 174, city: shelbyville,us
# Processing Record 175, city: ingham,au
# Processing Record 176, city: bredasdorp,za
# Processing Record 177, city: palencia,es
# Processing Record 178, city: te anau,nz
# Processing Record 179, city: esperance,au
# Processing Record 180, city: general roca,ar
# City olafsvik,is not found
# Processing Record 181, city: povorino,ru
# Processing Record 182, city: luderitz,na
# Processing Record 183, city: berlevag,no
# City palabuhanratu,id not found
# Processing Record 184, city: ust-ordynskiy,ru
# Processing Record 185, city: weligama,lk
# Processing Record 186, city: tasiilaq,gl
# City toftir,fo not found
# Processing Record 187, city: lashma,ru
# Processing Record 188, city: evensk,ru
# City goderich,sl not found
# Processing Record 189, city: havre-saint-pierre,ca
# Processing Record 190, city: asilah,ma
# Processing Record 191, city: khasan,ru
# Processing Record 192, city: sibolga,id
# Processing Record 193, city: riyadh,sa
# Processing Record 194, city: tuktoyaktuk,ca
# Processing Record 195, city: vanavara,ru
# Processing Record 196, city: chicama,pe
# Processing Record 197, city: gizo,sb
# Processing Record 198, city: porto novo,cv
# Processing Record 199, city: rock sound,bs
# Processing Record 200, city: lorengau,pg
# Processing Record 201, city: harbour breton,ca
# Processing Record 202, city: port shepstone,za
# City barbar,sd not found
# Processing Record 203, city: grodkow,pl
# Processing Record 204, city: yellowknife,ca
# Processing Record 205, city: srednekolymsk,ru
# Processing Record 206, city: caramay,ph
# Processing Record 207, city: linhares,br
# Processing Record 208, city: lebu,cl
# City svetlyy,ru not found
# Processing Record 209, city: vila velha,br
# Processing Record 210, city: cabiraoan,ph
# Processing Record 211, city: kulhudhuffushi,mv
# Processing Record 212, city: moussoro,td
# Processing Record 213, city: norman wells,ca
# Processing Record 214, city: turukhansk,ru
# City oga,jp not found
# Processing Record 215, city: upernavik,gl
# Processing Record 216, city: deloraine,ca
# Processing Record 217, city: tungor,ru
# Processing Record 218, city: oranjestad,aw
# Processing Record 219, city: timra,se
# Processing Record 220, city: zabaykalsk,ru
# Processing Record 221, city: sao filipe,cv
# Processing Record 222, city: venado tuerto,ar
# Processing Record 223, city: ardmore,us
# Processing Record 224, city: coquimbo,cl
# Processing Record 225, city: vieux-habitants,gp
# Processing Record 226, city: constitucion,mx
# Processing Record 227, city: mednogorsk,ru
# Processing Record 228, city: flinders,au
# Processing Record 229, city: le mars,us
# Processing Record 230, city: eyrarbakki,is
# Processing Record 231, city: port alfred,za
# Processing Record 232, city: pisco,pe
# Processing Record 233, city: mayo,ca
# Processing Record 234, city: chuy,uy
# Processing Record 235, city: inirida,co
# Processing Record 236, city: cape town,za
# Processing Record 237, city: kruisfontein,za
# City saint anthony,ca not found
# City samusu,ws not found
# Processing Record 238, city: clyde river,ca
# Processing Record 239, city: lima,pe
# Processing Record 240, city: ossora,ru
# Processing Record 241, city: charlottetown,ca
# Processing Record 242, city: krian,id
# Processing Record 243, city: fare,pf
# Processing Record 244, city: akhalgori,ge
# Processing Record 245, city: chalus,ir
# City lasa,cn not found
# Processing Record 246, city: geraldton,au
# City marcona,pe not found
# Processing Record 247, city: kaitangata,nz
# Processing Record 248, city: kahului,us
# City vaitupu,wf not found
# Processing Record 249, city: tobol,kz
# Processing Record 250, city: bilma,ne
# Processing Record 251, city: hamilton,bm
# Processing Record 252, city: kavieng,pg
# Processing Record 253, city: nanortalik,gl
# Processing Record 254, city: banjar,id
# Processing Record 255, city: dunedin,nz
# Processing Record 256, city: nanning,cn
# Processing Record 257, city: cacapava do sul,br
# Processing Record 258, city: barranca,pe
# City tsihombe,mg not found
# Processing Record 259, city: nishihara,jp
# Processing Record 260, city: novo aripuana,br
# Processing Record 261, city: makakilo city,us
# Processing Record 262, city: watertown,us
# Processing Record 263, city: san rafael,ar
# City kismayo,so not found
# Processing Record 264, city: marquette,us
# Processing Record 265, city: morant bay,jm
# Processing Record 266, city: khudumelapye,bw
# City malwan,in not found
# Processing Record 267, city: khatanga,ru
# Processing Record 268, city: richards bay,za
# Processing Record 269, city: sangar,ru
# Processing Record 270, city: fairbanks,us
# City rafael reyes,co not found
# Processing Record 271, city: illora,es
# City wulanhaote,cn not found
# Processing Record 272, city: tuy hoa,vn
# Processing Record 273, city: severo-kurilsk,ru
# Processing Record 274, city: heilbad heiligenstadt,de
# Processing Record 275, city: ust-uda,ru
# Processing Record 276, city: kansanshi,zm
# Processing Record 277, city: igrim,ru
# Processing Record 278, city: bolobo,cd
# City sorvag,fo not found
# City ye,mm not found
# Processing Record 279, city: vestmannaeyjar,is
# Processing Record 280, city: mitsamiouli,km
# Processing Record 281, city: lambarene,ga
# Processing Record 282, city: ixtapa,mx
# City mergui,mm not found
# Processing Record 283, city: xingyi,cn
# Processing Record 284, city: talnakh,ru
# Processing Record 285, city: touros,br
# City attawapiskat,ca not found
# City tuggurt,dz not found
# Processing Record 286, city: port hardy,ca
# Processing Record 287, city: cairns,au
# Processing Record 288, city: phonhong,la
# Processing Record 289, city: barsovo,ru
# Processing Record 290, city: tarbert,gb
# Processing Record 291, city: guigue,ve
# Processing Record 292, city: guatire,ve
# Processing Record 293, city: jaisinghnagar,in
# Processing Record 294, city: yulara,au
# Processing Record 295, city: waipawa,nz
# Processing Record 296, city: salalah,om
# Processing Record 297, city: sisimiut,gl
# Processing Record 298, city: progreso,mx
# Processing Record 299, city: huarmey,pe
# City temaraia,ki not found
# Processing Record 300, city: adrar,dz
# Processing Record 301, city: nasirabad,pk
# Processing Record 302, city: badarpur,in
# Processing Record 303, city: nuuk,gl
# Processing Record 304, city: lubao,cd
# Processing Record 305, city: borovoy,ru
# Processing Record 306, city: tateyama,jp
# Processing Record 307, city: vardo,no
# Processing Record 308, city: saint-pierre,pm
# Processing Record 309, city: funtua,ng
# Processing Record 310, city: yarada,in
# Processing Record 311, city: kloulklubed,pw
# Processing Record 312, city: noumea,nc
# City ijaki,ki not found
# Processing Record 313, city: sola,vu
# City umzimvubu,za not found
# Processing Record 314, city: takestan,ir
# Processing Record 315, city: riverton,nz
# Processing Record 316, city: hovd,mn
# City haibowan,cn not found
# Processing Record 317, city: great falls,us
# Processing Record 318, city: sarkand,kz
# Processing Record 319, city: tra vinh,vn
# City grand river south east,mu not found
# Processing Record 320, city: harper,lr
# City nizhneyansk,ru not found
# Processing Record 321, city: bastia,fr
# City tungkang,tw not found
# Processing Record 322, city: urucara,br
# Processing Record 323, city: tadine,nc
# Processing Record 324, city: ladovskaya balka,ru
# City catamarca,ar not found
# Processing Record 325, city: port blair,in
# Processing Record 326, city: mahebourg,mu
# Processing Record 327, city: ibra,om
# Processing Record 328, city: anadyr,ru
# Processing Record 329, city: moree,au
# Processing Record 330, city: anori,br
# Processing Record 331, city: neiafu,to
# Processing Record 332, city: tarata,pe
# Processing Record 333, city: novyy yegorlyk,ru
# Processing Record 334, city: hibbing,us
# Processing Record 335, city: melo,uy
# Processing Record 336, city: ilinskiy,ru
# Processing Record 337, city: astoria,us
# Processing Record 338, city: hay river,ca
# Processing Record 339, city: mount isa,au
# Processing Record 340, city: methven,nz
# Processing Record 341, city: koflach,at
# City avera,pf not found
# Processing Record 342, city: turbat,pk
# Processing Record 343, city: guaruja,br
# Processing Record 344, city: qujing,cn
# Processing Record 345, city: gazojak,tm
# Processing Record 346, city: margate,za
# Processing Record 347, city: namatanai,pg
# City pemangkat,id not found
# Processing Record 348, city: pyay,mm
# Processing Record 349, city: suozhen,cn
# City bengkalis,id not found
# Processing Record 350, city: harindanga,in
# Processing Record 351, city: kurchum,kz
# Processing Record 352, city: iquitos,pe
# Processing Record 353, city: copacabana,bo
# Processing Record 354, city: puerto leguizamo,co
# Processing Record 355, city: ochtrup,de
# City khonuu,ru not found
# Processing Record 356, city: oparino,ru
# City doha,kw not found
# Processing Record 357, city: santa rosa,bo
# City viligili,mv not found
# Processing Record 358, city: kang,bw
# Processing Record 359, city: easton,us
# Processing Record 360, city: lompoc,us
# City vylgort,ru not found
# City lolua,tv not found
# Processing Record 361, city: parrita,cr
# Processing Record 362, city: vila franca do campo,pt
# Processing Record 363, city: yatou,cn
# Processing Record 364, city: flin flon,ca
# Processing Record 365, city: butembo,cd
# Processing Record 366, city: manakara,mg
# Processing Record 367, city: sao paulo de olivenca,br
# Processing Record 368, city: priladozhskiy,ru
# Processing Record 369, city: yerbogachen,ru
# City betki,ru not found
# Processing Record 370, city: lazaro cardenas,mx
# Processing Record 371, city: auki,sb
# Processing Record 372, city: sao joao da barra,br
# Processing Record 373, city: berdigestyakh,ru
# Processing Record 374, city: coihaique,cl
# Processing Record 375, city: kitgum,ug
# Processing Record 376, city: praia da vitoria,pt
# Processing Record 377, city: lodja,cd
# Processing Record 378, city: poum,nc
# Processing Record 379, city: buraydah,sa
# Processing Record 380, city: taoudenni,ml
# Processing Record 381, city: tarko-sale,ru
# Processing Record 382, city: almenara,br
# Processing Record 383, city: ongandjera,na
# Processing Record 384, city: nara,ml
# City cumaribo,co not found
# City tabiauea,ki not found
# Processing Record 385, city: camabatela,ao
# Processing Record 386, city: burnie,au
# Processing Record 387, city: road town,vg
# City nguiu,au not found
# Processing Record 388, city: kununurra,au
# Processing Record 389, city: rudnogorsk,ru
# Processing Record 390, city: longyearbyen,sj
# Processing Record 391, city: yeppoon,au
# Processing Record 392, city: luanda,ao
# Processing Record 393, city: camacupa,ao
# Processing Record 394, city: chumikan,ru
# Processing Record 395, city: nelson bay,au
# Processing Record 396, city: nabire,id
# City illela,ne not found
# Processing Record 397, city: san cristobal,ec
# Processing Record 398, city: roma,au
# Processing Record 399, city: kinablangan,ph
# Processing Record 400, city: acari,pe
# City louisbourg,ca not found
# Processing Record 401, city: wadsworth,us
# Processing Record 402, city: epe,ng
# Processing Record 403, city: qasigiannguit,gl
# Processing Record 404, city: sepuka,tz
# Processing Record 405, city: kamina,cd
# Processing Record 406, city: kysyl-syr,ru
# Processing Record 407, city: linxia,cn
# Processing Record 408, city: pochutla,mx
# Processing Record 409, city: hauterive,ca
# Processing Record 410, city: derzhavinsk,kz
# Processing Record 411, city: heilbron,za
# Processing Record 412, city: puerto escondido,mx
# Processing Record 413, city: rebrikha,ru
# Processing Record 414, city: valdivia,cl
# Processing Record 415, city: okha,ru
# Processing Record 416, city: deputatskiy,ru
# Processing Record 417, city: kuandian,cn
# Processing Record 418, city: beyneu,kz
# Processing Record 419, city: khandyga,ru
# Processing Record 420, city: hambantota,lk
# Processing Record 421, city: zhangjiakou,cn
# Processing Record 422, city: kalevala,ru
# Processing Record 423, city: bloomsburg,us
# Processing Record 424, city: souillac,mu
# City liniere,ca not found
# Processing Record 425, city: barra,br
# City el alto,pe not found
# City gat,ly not found
# Processing Record 426, city: haines junction,ca
# City galgani,sd not found
# Processing Record 427, city: quzhou,cn
# City abu samrah,qa not found
# Processing Record 428, city: grand gaube,mu
# Processing Record 429, city: popondetta,pg
# Processing Record 430, city: graaff-reinet,za
# Processing Record 431, city: kondinskoye,ru
# Processing Record 432, city: pokhara,np
# City doctor pedro p. pena,py not found
# Processing Record 433, city: omboue,ga
# Processing Record 434, city: udachnyy,ru
# Processing Record 435, city: guilin,cn
# Processing Record 436, city: kirensk,ru
# Processing Record 437, city: maceio,br
# Processing Record 438, city: havelock,us
# Processing Record 439, city: sur,om
# Processing Record 440, city: chazuta,pe
# Processing Record 441, city: komsomolskiy,ru
# Processing Record 442, city: aksha,ru
# Processing Record 443, city: banda aceh,id
# City cozumel,mx not found
# Processing Record 444, city: saint-denis,re
# Processing Record 445, city: labuhan,id
# Processing Record 446, city: huescar,es
# Processing Record 447, city: hobyo,so
# Processing Record 448, city: kontagora,ng
# Processing Record 449, city: walvis bay,na
# Processing Record 450, city: kampene,cd
# Processing Record 451, city: kranj,si
# Processing Record 452, city: aklavik,ca
# Processing Record 453, city: messina,za
# Processing Record 454, city: alyangula,au
# Processing Record 455, city: sobolevo,ru
# Processing Record 456, city: chifeng,cn
# Processing Record 457, city: hofn,is
# Processing Record 458, city: alice springs,au
# Processing Record 459, city: kaspiyskiy,ru
# Processing Record 460, city: meulaboh,id
# Processing Record 461, city: san carlos de bariloche,ar
# Processing Record 462, city: mehamn,no
# Processing Record 463, city: phangnga,th
# Processing Record 464, city: honningsvag,no
# Processing Record 465, city: araguari,br
# Processing Record 466, city: sweetwater,us
# Processing Record 467, city: kungurtug,ru
# Processing Record 468, city: banepa,np
# City mrirt,ma not found
# Processing Record 469, city: ponta delgada,pt
# Processing Record 470, city: den helder,nl
# Processing Record 471, city: wadi maliz,tn
# City saleaula,ws not found
# Processing Record 472, city: almirante,pa
# Processing Record 473, city: onda,es
# Processing Record 474, city: amherst,ca
# Processing Record 475, city: novyy urgal,ru
# Processing Record 476, city: baykit,ru
# Processing Record 477, city: vurnary,ru
# Processing Record 478, city: pervomayskiy,ru
# Processing Record 479, city: rome,us
# Processing Record 480, city: amuntai,id
# Processing Record 481, city: padang,id
# Processing Record 482, city: guerrero negro,mx
# Processing Record 483, city: mporokoso,zm
# Processing Record 484, city: masiga,ph
# Processing Record 485, city: kalyazin,ru
# Processing Record 486, city: aksu,cn
# Processing Record 487, city: almaznyy,ru
# Processing Record 488, city: tiznit,ma
# Processing Record 489, city: gornopravdinsk,ru
# Processing Record 490, city: otukpo,ng
# City solovetskiy,ru not found
# Processing Record 491, city: morropon,pe
# Processing Record 492, city: antalaha,mg
# Processing Record 493, city: chipinge,zw
# Processing Record 494, city: kawalu,id
# Processing Record 495, city: xingcheng,cn
# Processing Record 496, city: kangaba,ml
# Processing Record 497, city: christchurch,nz
# City sakakah,sa not found
# Processing Record 498, city: mae tha,th
# Processing Record 499, city: jasper,ca
# Processing Record 500, city: norrkoping,se
# City requena,pe not found
# City chom bung,th not found
# Processing Record 501, city: macas,ec
# Processing Record 502, city: malmesbury,za
# Processing Record 503, city: jertih,my
# Processing Record 504, city: oksfjord,no
# Processing Record 505, city: zacualpan,mx
# Processing Record 506, city: damietta,eg
# Processing Record 507, city: rajapur,in
# Processing Record 508, city: palmer,us
# Processing Record 509, city: tezu,in
# Processing Record 510, city: port macquarie,au
# Processing Record 511, city: mabaruma,gy
# Processing Record 512, city: kinwat,in
# Processing Record 513, city: visavadar,in
# Processing Record 514, city: kalmunai,lk
# Processing Record 515, city: yarmouth,ca
# Processing Record 516, city: gushikawa,jp
# Processing Record 517, city: chenzhou,cn
# Processing Record 518, city: mao,td
# Processing Record 519, city: okhotsk,ru
# Processing Record 520, city: hami,cn
# Processing Record 521, city: townsville,au
# City haapu,pf not found
# Processing Record 522, city: gedo,et
# Processing Record 523, city: matinhos,br
# Processing Record 524, city: bloomfield,us
# Processing Record 525, city: kaabong,ug
# Processing Record 526, city: hualmay,pe
# Processing Record 527, city: mecca,sa
# Processing Record 528, city: kesova gora,ru
# Processing Record 529, city: ormara,pk
# Processing Record 530, city: virginia beach,us
# Processing Record 531, city: makasar,id
# Processing Record 532, city: guarapari,br
# Processing Record 533, city: yanam,in
# Processing Record 534, city: jojoima,sl
# Processing Record 535, city: sharjah,ae
# Processing Record 536, city: sirjan,ir
#
# Data Retreival Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# name columns and convert to a datafram
column_names = ["City","Country","Latitude","Longitude","Date","Max Temperature","Humidity", "Wind Speed","Cloudiness"]
weather_data = pd.DataFrame(all_city_data, columns = column_names)

#Export data to csv
weather_data.to_csv(output_data_file, index=False)

#check number of rows for each variable
weather_data.count()
# Out:
# City               536
# Country            536
# Latitude           536
# Longitude          536
# Date               536
# Max Temperature    536
# Humidity           536
# Wind Speed         536
# Cloudiness         536
# dtype: int64

# %%
#check the dataframe
weather_data.head()
# Out:
#             City Country  Latitude  Longitude        Date  Max Temperature  \
# 0    Villamontes      BO    -21.26     -63.47  1563773636            68.41
# 1         Avarua      CK    -21.21    -159.78  1563773636            77.00
# 2  Aix-les-Bains      FR     45.69       5.91  1563773608            71.01
# 3         Atuona      PF     -9.80    -139.03  1563773637            79.93
# 4         Nieves      MX     24.00    -103.02  1563773637            65.17
#
#    Humidity  Wind Speed  Cloudiness
# 0        52        3.49           0
# 1        88        9.17          61
# 2        93        1.12          40
# 3        77       13.62          52
# 4        49        3.76          81

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#convert dates to m/d/y
dates = [datetime.utcfromtimestamp(int(d)).strftime('%m/%d/%Y') for d in weather_data["Date"]]
weather_data["Date"] = dates
#grab date value for chart title
weather_date = weather_data.iloc[0,4]
weather_data.head()
# Out:
#             City Country  Latitude  Longitude        Date  Max Temperature  \
# 0    Villamontes      BO    -21.26     -63.47  07/22/2019            68.41
# 1         Avarua      CK    -21.21    -159.78  07/22/2019            77.00
# 2  Aix-les-Bains      FR     45.69       5.91  07/22/2019            71.01
# 3         Atuona      PF     -9.80    -139.03  07/22/2019            79.93
# 4         Nieves      MX     24.00    -103.02  07/22/2019            65.17
#
#    Humidity  Wind Speed  Cloudiness
# 0        52        3.49           0
# 1        88        9.17          61
# 2        93        1.12          40
# 3        77       13.62          52
# 4        49        3.76          81

# %%
#scatter plot of the Latitude and temperature
plt.scatter(weather_data["Latitude"], weather_data["Max Temperature"], edgecolor = "k", alpha = .7)

#add title and labels
plt.title(f"City Latitude versus Max Temperature {weather_date}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

#show and save figure
plt.show()
plt.savefig("City Latitude vs Max Temperature.png")

# %% [markdown]
# #### Latitude vs. Tempurature Plot with polynomial regression fit

# %%
#Import Dependences
import operator
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

#define x and y variables for regression
x = weather_data["Latitude"]
y = weather_data["Max Temperature"]

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

#assign polynomial features, will use a second degree polynomial, perform regression fit and calculate fitted values
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(x)
model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)
#store coefficient vaules
fit_intercept = model.intercept_
fit_coef = model.coef_

fit_intercept = model.intercept_
fit_coef = model.coef_
coefs = fit_coef[0]
print(f"Fit is temperature = {fit_intercept[0]}+ {coefs[1]}*latitude + {coefs[2]}*latitude^2")

#calculate RMSE and R squared
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print(f"Residual Mean Squared Error is {rmse}")
print(f"R Squared is {r2}")

#Plot the data
plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
#plot fit of data
plt.plot(x, y_poly_pred, color='m')

#add title and labels
plt.title("City Latitude versus Max Temperature, Polynomial Fit")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

#show and save figure
plt.show()
plt.savefig("City Latitude vs Max Temperature Polynomial Regression Fit")
# Out:
# Fit is temperature = 77.84391654076137+ 0.3323862254641886*latitude + -0.009467075238045363*latitude^2
# Residual Mean Squared Error is 10.484869791988567
# R Squared is 0.4765951541923725

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plot latitude vs humidity
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], edgecolor = "k", alpha = .7)

#add title and labels
plt.title("City Latitude versus Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

#show and save figure
plt.show()
plt.savefig("City Latitude vs Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#plot latitude vs cloudiness
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], edgecolor = "k", alpha = .7)

#add title and labels
plt.title("City Latitude versus Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

#show and save figure
plt.show()
plt.savefig("City Latitude vs Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#plot latitude vs wind speed
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], edgecolor = "k", alpha = .7)

#add title and labels
plt.title("City Latitude versus Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

#show and save figure
plt.show()
plt.savefig("City Latitude vs Wind Speed.png")

# %%
#look at outlier observation
outlier_obs = weather_data.loc[weather_data['Wind Speed'] >30]
weather_data_otl_rem = weather_data.loc[weather_data['Wind Speed']<=30]
outlier_obs2 = outlier_obs.iloc[0,:]

# %%
#plot latitude vs wind speed
plt.scatter(weather_data_otl_rem["Latitude"], weather_data_otl_rem["Wind Speed"], edgecolor = "k", alpha = .7)

#add title and labels
plt.title("City Latitude versus Wind Speed, Outlier Removed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
print(f"The wind speed recorded at {outlier_obs2['City']}, {outlier_obs2['Country']} was {outlier_obs2['Wind Speed']} mph.")
#show and save figure
plt.show()
plt.savefig("City Latitude vs Wind Speed, Outlier Removed.png")
# Out:
# The wind speed recorded at Manta, EC was 69.12 mph.
